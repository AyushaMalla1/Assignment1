# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/assignment1
# !ls WHR-2024-5CS037.csv
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/assignment1
# WHR-2024-5CS037.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Problem - 1: Getting Started with Data Exploration -Some Warm up Exercises:
# 1. Data Exploration and Understanding:

# %% [markdown]
# #• Dataset Overview:

# %% [markdown]
# 1. Load the dataset and display the first 10 rows.

# %%
# Read the CSV file into a DataFrame
data = pd.read_csv("WHR-2024-5CS037.csv")

# Display the first 10 rows of the data
data.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. Identify the number of rows and columns in the dataset.

# %%
# Prints the shape of the DataFrame (rows, columns)
print("Number of row and columns: ", data.shape)
# Out:
# Number of row and columns:  (143, 9)

# %% [markdown]
# 3. List all the columns and their data types.

# %%
# Combine column names with their data types
columns_with_datatype = list(zip(data.columns, data.dtypes))

# Display the list of column names with corresponding data types
display(columns_with_datatype)
# Out:
# [('Country name', dtype('O')),
#  ('score', dtype('float64')),
#  ('Log GDP per capita', dtype('float64')),
#  ('Social support', dtype('float64')),
#  ('Healthy life expectancy', dtype('float64')),
#  ('Freedom to make life choices', dtype('float64')),
#  ('Generosity', dtype('float64')),
#  ('Perceptions of corruption', dtype('float64')),
#  ('Dystopia + residual', dtype('float64'))]

# %% [markdown]
# #basic statics:

# %% [markdown]
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
# Calculate mean, median, and standard deviation for the 'score' column
Mean = data['score'].mean()
Median = data['score'].median()
standard_deviation = data['score'].std()


# Print the results with two decimal places
print(f"Mean: {Mean:.2f}")
print(f"Median: {Median:.2f}")
print(f"Standard Deviation: {standard_deviation:.2f}")
# Out:
# Mean: 5.53
# Median: 5.79
# Standard Deviation: 1.17

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# Get the country with the highest and lowest happiness score
highest_happiness_score = data['Country name'][data['score'].idxmax()]
lowest_happiness_score = data['Country name'][data['score'].idxmin()]

# Print the results
print("Country with highest happiness score: " , highest_happiness_score)
print("Country with lowest happiness score: ", lowest_happiness_score)
# Out:
# Country with highest happiness score:  Finland
# Country with lowest happiness score:  Afghanistan

# %% [markdown]
# #Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# Check for missing values in each column and sum them
missing_values = data.isnull().sum()

# Display the count of missing values for each column
display("Missing values in dataset: ", missing_values)
# Out:
# 'Missing values in dataset: '
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# #Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
# Filter countries with a score greater than 7.5
highest_countries_score = data[data['score']> 7.5]

# Display the countries with scores greater than 7.5
display("countries with highest score greater than 7.5: ", highest_countries_score)
# Out:
# 'countries with highest score greater than 7.5: '
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
# Sort countries with a score greater than 7.5 by 'Log GDP per capita' in descending order and select the top 10
top_10_gdp = highest_countries_score.sort_values(by='Log GDP per capita', ascending = False).head(10)

# Display the top 10 countries based on GDP
display(top_10_gdp)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# #• Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
#
# Medium − (4 ≤ Score ≤ 6)
#
# High − (Score > 6)

# %%
def happiness_category(score):
  if score<4:
    return 'Low'
  elif score>4 and score<=6:
      return 'Medium'
  else:
      return 'High'
data['happiness category'] = data['score'].apply(happiness_category)
display(data)
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %% [markdown]
# #Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
top_10_happiest = data.nlargest(10, 'score')
top_10_happiest.plot(kind = 'bar', x ='Country name', y='score',color='brown') # Changed 'country name' to 'Country name'
plt.title('Top 10 happiest countries by happiness score ')
plt.xlabel('Country name')
plt.ylabel('score')
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_10_unhappiest = data.nsmallest(10, 'score')
plt.figure(figsize=(10, 6))
top_10_unhappiest.plot(kind = 'line', x ='Country name', y='score', marker='o', color='blue') # Changed 'country name' to 'Country name'
plt.title('Top 10 unhappiest countries by happiness score ')
plt.xticks(rotation=45)
plt.xlabel('Country name')
plt.ylabel('score')
plt.show()

# %% [markdown]
# •Plot a histogram for the Score column to show its distribution and also interpret.

# %%
data['score'].plot(kind = 'hist', edgecolor = 'white', color='pink')
plt.title('Distribution of happiness scores')
plt.xlabel('score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# •Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
categories = {'low': 'red', 'Medium': 'blue', 'High':'green'}
for category, color in categories.items():
  subset = data[data['happiness category'] == category]
  plt.scatter(subset['Log GDP per capita'], subset['score'], label=category, color=color)
plt.title('relationship between GDP per capita and score')
plt.xlabel('log GDP per capita')
plt.ylabel('score')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Problem - 2 - Some Advance Data Exploration Task:
# Task1 - Setup Task - Preparing the South-Asia Dataset:

# %% [markdown]
# Steps:
# 1. Define the countries in South Asia with a list for example:
#
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]

# %% [markdown]
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}

# %%
# Define the list of South Asian countries
south_asian_countries = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India','Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# Filter the DataFrame
south_asian_data = data[data['Country name'].isin(south_asian_countries)]

# Display the filtered data
display(south_asian_data)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_data.to_csv('south_asian_data.csv', index=False)

# %% [markdown]
# #Task2 - Composite Score Ranking:
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
south_asian_data.loc[:,'Composite Score'] = (0.40 * south_asian_data['Log GDP per capita']
                                             + 0.30 * south_asian_data['Social support']
                                             + 0.30 * south_asian_data['Healthy life expectancy'])
display(south_asian_data)
# Out:
# <ipython-input-183-d7e82a3d6359>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asian_data.loc[:,'Composite Score'] = (0.40 * south_asian_data['Log GDP per capita']
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
south_asian_sorted = south_asian_data.sort_values('Composite Score', ascending=False)
display(south_asian_sorted)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 127    Sri Lanka  3.898               1.361           1.179
# 92         Nepal  5.158               0.965           0.990
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 127                    0.586                         0.583       0.144
# 92                     0.443                         0.653       0.209
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
top5_countries = south_asian_sorted.head(5)
plt.barh(top5_countries['Country name'], top5_countries['Composite Score'], color = 'brown')
plt.title('Top 5 countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Countries')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
plt.scatter(south_asian_data['score'], south_asian_data['Composite Score'], color='blue')
plt.title('Relationship between Score and Composite Score')
plt.xlabel('Score')
plt.ylabel('Composite Score')
plt.grid()
plt.show()

# %% [markdown]
# #Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.

# %%
Q1_score = south_asian_data['score'].quantile(0.25)
Q3_score = south_asian_data['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

Q1_gdp = south_asian_data['Log GDP per capita'].quantile(0.25)
Q3_gdp = south_asian_data['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

outliers_score = south_asian_data[(south_asian_data['score']<(Q1_score - 1.5* IQR_score))|
                                  (south_asian_data['score']>(Q3_score + 1.5* IQR_score))]

gdp_outliers = south_asian_data[(south_asian_data['Log GDP per capita']<(Q1_gdp - 1.5 *IQR_gdp))|
                                (south_asian_data['Log GDP per capita']> (Q3_gdp + 1.5 * IQR_gdp))]

outliers =pd.concat([outliers_score, gdp_outliers]).drop_duplicates()
display(outliers)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual happiness category  \
# 142                      0.088                0.672                Low
#
#      Composite Score
# 142           0.3238

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
plt.scatter(south_asian_data["Log GDP per capita"], south_asian_data["score"], color="blue", label="Non-Outliers")
plt.scatter(outliers["Log GDP per capita"], outliers["score"], color="brown", label="Outliers")
plt.xlabel("Log GDP per capita")
plt.ylabel("score")
plt.title("Scatter Plot of GDP per Capita vs. Score (Outliers Highlighted)")
plt.legend()
plt.show()

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %% [markdown]
# 1) Characteristics of Outliers:
#
# Extreme Values: Outliers are significantly higher or lower than other data points.
#
# Deviation from the Pattern: They don’t follow the same trend as most data.
#
# Rare Occurrences: Outliers are often unusual and not typical of the general population.
#
#
#
# 2) Potential Impact on Regional Averages:
#
# Skewing the Average: Outliers can distort the mean, making it unrepresentative.
#
# Distorting Trends: They can change perceived patterns or trends.
#
# Influencing Decisions: Outliers can lead to poor decisions if not properly addressed.

# %% [markdown]
# #Task4 - Exploring Trends Across Metrics:
# Tasks:
# 1) Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
freedom_correlation = south_asian_data['score'].corr(south_asian_data['Freedom to make life choices'])
generosity_correlation = south_asian_data['score'].corr(south_asian_data['Generosity'])
print("Correlation between Score and Freedom to Make Life Choices: ", freedom_correlation)
print("Correlation between Score and Generosity: ", generosity_correlation)
# Out:
# Correlation between Score and Freedom to Make Life Choices:  0.8005185224163315
# Correlation between Score and Generosity:  0.874512371253192

# %% [markdown]
# 2) Create scatter plots with trendlines for these metrics against the Score.

# %%
sns.lmplot(x='Freedom to make life choices', y='score', data=south_asian_data, line_kws={'color':'brown'})
plt.title('Scatter plot with trendline for Freedom to Make Life Choices')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()

sns.lmplot(x='Generosity', y='score', data=south_asian_data, line_kws={'color':'green'})
plt.title('Scatter plot with trendline for Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %% [markdown]
# 1) Strongest Relationship(Generosity):
#
# Generosity shows the strongest correlation with Happiness Score (0.8745), highlighting the significant role of acts of giving and community support in South Asian countries.
#
# Implication: Promoting generosity through community welfare initiatives can substantially enhance happiness.
#
#
# 2) Weakest Relationship(Freedom to Make Life Choices):
#
# Freedom to Make Life Choices has a slightly weaker correlation (0.8005) with happiness. While autonomy is important, it plays a smaller role compared to generosity in this context.
#
# Implication: Increasing personal freedoms can improve happiness but may be less impactful without addressing collective well-being.

# %% [markdown]
# #Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
south_asian_data.loc[:, 'GDP-Score Gap'] = south_asian_data['Log GDP per capita'] - south_asian_data['score']
display(south_asian_data)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
# Sort South Asian countries by GDP-Score Gap in ascending order and take top 3 countries
ascending_gap = south_asian_data.sort_values(by='GDP-Score Gap', ascending=True).head(3)

# Sort South Asian countries by GDP-Score Gap in descending order and take top 3 countries
descending_gap = south_asian_data.sort_values(by='GDP-Score Gap', ascending=False).head(3)

# Display the results
print("Top 3 South Asian Countries with the Smallest GDP-Score Gap (Ascending):")
display(ascending_gap[['Country name', 'GDP-Score Gap']])  # Show relevant columns

print("\nTop 3 South Asian Countries with the Largest GDP-Score Gap (Descending):")
display(descending_gap[['Country name', 'GDP-Score Gap']])  # Show relevant columns
# Out:
# Top 3 South Asian Countries with the Smallest GDP-Score Gap (Ascending):
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888
# Top 3 South Asian Countries with the Largest GDP-Score Gap (Descending):
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
#Get top3 countries with positive and negative gaps
top_positive_gap = descending_gap.head(3)
top_negative_gap = ascending_gap.head(3)
#Plot positive gaps
plt.bar(top_positive_gap['Country name'], top_positive_gap['GDP-Score Gap'], color='skyblue', label='Positive Gaps')
#Plot negative gaps
plt.bar(top_negative_gap['Country name'], top_negative_gap['GDP-Score Gap'], color='pink', label='Negative Gaps')
#Set the title
plt.title('Top 3 Countries with Largest Positive and Negative GDP-Score Gaps')
#Set the x and y labels
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')
#Add legend
plt.legend()
#Display the plot
plt.show()

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %% [markdown]
# 1) Reasons Behind Development Gaps in South Asia:
#
# Colonial Legacy: Resource extraction with minimal reinvestment; poor infrastructure post-independence.
#
# Governance Issues: Political instability, corruption, and inefficiencies disrupt development.
#
# Social Inequality: Caste, gender, and ethnic disparities hinder equitable growth.
#
#
#
# 2) Implications for South Asian Countries:
#
# Economic: Stunted growth, brain drain, and persistent income disparities.
#
# Social: Increased unrest, limited mobility for marginalized communities.
#
# Geopolitical: Regional instability and weakened diplomatic ties.

# %% [markdown]
# # Problem - 3 - Comparative Analysis:
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
# #Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries.
#
#  For hint use thefollowing list:
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]
#
# #Complete the following task:

# %%
# Middle Eastern countries list
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# Filter the dataset for Middle Eastern countries
middle_east_data = data[data['Country name'].isin(middle_east_countries)]
print("Filtered Middle East Dataset:")
display(middle_east_data)
# Out:
# Filtered Middle East Dataset:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# #1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
# Calculate mean and standard deviation for South Asia and Middle East
mean_south_asia = south_asian_data['score'].mean()
std_south_asia = south_asian_data['score'].std()

mean_middle_east = middle_east_data['score'].mean()
std_middle_east = middle_east_data['score'].std()

print("\nDescriptive Statistics:")
print(f"South Asia - Mean: {mean_south_asia}, Std Dev: {std_south_asia}")
print(f"Middle East - Mean: {mean_middle_east}, Std Dev: {std_middle_east}")

# Determine which region has higher average happiness
higher_avg_region = "South Asia" if mean_south_asia > mean_middle_east else "Middle East"
print(f"\nRegion with higher average happiness score: {higher_avg_region}")
# Out:
# Descriptive Statistics:
# South Asia - Mean: 3.895666666666667, Std Dev: 1.1770690152521504
# Middle East - Mean: 5.412100000000001, Std Dev: 1.5662011684327144
#
# Region with higher average happiness score: Middle East

# %% [markdown]
# #2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
# Top 3 Happiest and Bottom 3 for South Asia
top3_south_asian = south_asian_data.nlargest(3, "score")
bottom3_south_asia = south_asian_data.nsmallest(3, "score")

# Top 3 Happiest and Bottom 3 for Middle East
top3_middle_east = middle_east_data.nlargest(3, "score")
bottom3_middle_east = middle_east_data.nsmallest(3, "score")

# Create the plot
plt.figure(figsize=(12, 10))

# Subplot 1: Top 3 happiest countries
plt.subplot(2, 1, 1)
plt.bar(top3_south_asian['Country name'], top3_south_asian['score'], color='blue', label='South Asia')
plt.bar(top3_middle_east['Country name'], top3_middle_east['score'], color='green', label='Middle East')
plt.title("Top 3 Happiest Countries", fontsize=16, weight='bold')
plt.ylabel("Happiness Score", fontsize=12)
plt.legend(fontsize=10)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# Subplot 2: Bottom 3 happiest countries
plt.subplot(2, 1, 2)
plt.bar(bottom3_south_asia['Country name'], bottom3_south_asia['score'], color='darkblue', label='South Asia')
plt.bar(bottom3_middle_east['Country name'], bottom3_middle_east['score'], color='darkgreen', label='Middle East')
plt.title("Bottom 3 Happiest Countries", fontsize=16, weight='bold')
plt.xlabel("Country", fontsize=12)
plt.ylabel("Happiness Score", fontsize=12)
plt.legend(fontsize=10)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# Adjust layout to ensure proper spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# #3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']

# Calculate means for South Asia and Middle East
means = {'South Asia': south_asian_data[metrics].mean(),'Middle East': middle_east_data[metrics].mean()}

# Create DataFrame for comparison and plot grouped bar chart
comparison_df = pd.DataFrame(means).T
comparison_df.plot(kind='bar', figsize=(10, 6), colormap='coolwarm')
plt.title('Metric Comparisons between South Asia and Middle East')
plt.ylabel('Average Value')
plt.xticks(rotation=0)
plt.show()

# Identify the metric with the largest disparity
largest_disparity = (comparison_df.loc['South Asia'] - comparison_df.loc['Middle East']).abs().idxmax()
print(f"Metric with largest disparity: {largest_disparity}")
# Out:
# Metric with largest disparity: Social support

# %% [markdown]
# #4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
# Calculate range and coefficient of variation for both regions
range_sa = south_asian_data['score'].max() - south_asian_data['score'].min()
cv_sa = south_asian_data['score'].std() / south_asian_data['score'].mean()

range_me = middle_east_data['score'].max() - middle_east_data['score'].min()
cv_me = middle_east_data['score'].std() / middle_east_data['score'].mean()

# Print the results
print(f"South Asia - Range: {range_sa:.2f}, CV: {cv_sa:.2f}")
print(f"Middle East - Range: {range_me:.2f}, CV: {cv_me:.2f}")

# Find the region with greater variability using max function
greater_variability_region = max(('South Asia', 'Middle East'), key=lambda region: cv_sa if region == 'South Asia' else cv_me)
print(f"The region with greater variability in happiness is: {greater_variability_region}")
# Out:
# South Asia - Range: 3.44, CV: 0.30
# Middle East - Range: 4.63, CV: 0.29
# The region with greater variability in happiness is: South Asia

# %% [markdown]
# #5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.

# %%
# Pearson correlation between Score and Freedom to Make Life Choices, and Score and Generosity for South Asia
south_asia_corr_freedom = south_asian_data[['score', 'Freedom to make life choices']].corr(method='pearson')
south_asia_corr_generosity = south_asian_data[['score', 'Generosity']].corr(method='pearson')

# Pearson correlation for Middle East
middle_east_corr_freedom = middle_east_data[['score', 'Freedom to make life choices']].corr(method='pearson')
middle_east_corr_generosity = middle_east_data[['score', 'Generosity']].corr(method='pearson')

# Display the correlation results
print(f"South Asia - Freedom to Make Life Choices vs Score: {south_asia_corr_freedom.iloc[0, 1]}")
print(f"South Asia - Generosity vs Score: {south_asia_corr_generosity.iloc[0, 1]}")

print(f"Middle East - Freedom to Make Life Choices vs Score: {middle_east_corr_freedom.iloc[0, 1]}")
print(f"Middle East - Generosity vs Score: {middle_east_corr_generosity.iloc[0, 1]}")
# Out:
# South Asia - Freedom to Make Life Choices vs Score: 0.8005185224163315
# South Asia - Generosity vs Score: 0.8745123712531921
# Middle East - Freedom to Make Life Choices vs Score: 0.8632202433827542
# Middle East - Generosity vs Score: 0.627523653696418

# %% [markdown]
# • Create scatter plots to visualize and interpret the relationships.

# %%
# Scatter plots with trendlines
for metric in ['Freedom to make life choices', 'Generosity']:
    plt.figure(figsize=(10, 6))
    plt.scatter(south_asian_data[metric], south_asian_data['score'], color='green', label='South Asia')
    plt.scatter(middle_east_data[metric], middle_east_data['score'], color='blue', label='Middle East')
    plt.title(f'{metric} vs. Happiness Score')
    plt.xlabel(metric)
    plt.ylabel('Happiness Score')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# #6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
# Detect outliers using IQR method
def detect_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    outliers = data[(data[column] < Q1 - 1.5 * IQR) | (data[column] > Q3 + 1.5 * IQR)]
    return outliers

outliers_sa = detect_outliers(south_asian_data, 'score')
outliers_me = detect_outliers(middle_east_data, 'score')

# Plot outliers
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asian_data, label='Non-Outliers (SA)', color='blue')
sns.scatterplot(x='Log GDP per capita', y='score', data=outliers_sa, label='Outliers (SA)', color='red')
plt.title('Outliers in South Asia')
plt.grid()
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_data, label='Non-Outliers (ME)', color='blue')
sns.scatterplot(x='Log GDP per capita', y='score', data=outliers_me, label='Outliers (ME)', color='red')
plt.title('Outliers in Middle East')
plt.grid()
plt.show()

# %% [markdown]
# #7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# Task 7: Boxplots for Score Distribution
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=pd.concat([south_asian_data.assign(Region='South Asia'),middle_east_data.assign(Region='Middle East')]))
plt.title('Score Distribution: South Asia vs. Middle East')
plt.grid()
plt.show()
